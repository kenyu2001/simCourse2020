# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov  6 11:40:16 2020

@author: Administrator
"""
# 引入数学计算模块
import math
# 引用随机数模块
import random

# 排队者（人）类
class Person:    
    # 到达、开始服务、离开时间点、人员ID
    arriveTime = 0
    serviceBeginTime = 0
    departTime = 0
    pID = 0
    
    # 排队者实时状态：0即未进入；1即到达并排队中；2即服务中；3即离开了   
    status = 0
    
    def __init__(self, arriveTime, pid):
        self.arriveTime = arriveTime
        self.status = 1
        self.pID = pid

# 队列（排队）类
class QueueSim:
    
    # 数组类变量
    # 服务站状态：0即空闲；1即忙碌
    serverStatus = 0
    
    # 到达排队队列；Person一个挨一个
    # 队列中第一个Person为正在服务中
    queueList = []
    
    # 事件队列
    # eventList = []
    
    # 所有离开的Person队列，用于统计方便
    deptList = []
    
    nextArrTime = 0
    # 最近一个离开时间，初始值必须最大值！
    nextDeptTime = 999999
    
    # 实时变量
    # 仿真计时：实时时间
    simClock = 0
    
    # 统计变量
    # 设备累计繁忙时间
    servTimeAccum = 0    
    # 累计等待时间
    delayTimeAccm = 0
    # 累计总等待时间
    totalTimeAccm = 0
    
    # 仿真人数统计
    maxPeopleNums = 0
    # 人员编号
    personID = 0
    
    # 负指数分布参数
    arrMean = 0
    servMean = 0
    
    def initialize(self, num, aMean, sMean): 
        self.maxPeopleNums = num
        self.arrMean = aMean
        self.servMean = sMean
        self.nextArrTime = self.expRand(self.arrMean)

        print("Simulation initialize()--nextArrTime: " 
              + str(round(self.nextArrTime, 2))
              + " nextDeptTime: " + str(round(self.nextDeptTime, 2)))
    
    # 仿真终止函数    
    def isFinished(self):
        if(len(self.deptList) >= self.maxPeopleNums):
            return True
        
        else:
            return False        
               
    # 时间步进函数    
    def clockUpd(self):
        
        # 检测是否到达“满员”，闭门谢客
        if(self.personID >= self.maxPeopleNums):
            print(str(self.personID) 
                  + ' persons has arrived! $ 准备收工!')
            self.nextArrTime = 999999
            print('clockUpd()--nextArrTime: ' 
                  + str(round(self.nextArrTime, 2)))
        
        # 对比，找出下一个事件时间
        if (self.nextArrTime < self.nextDeptTime):
            self.simClock = self.nextArrTime
        else:
            self.simClock = self.nextDeptTime
        
        # print('clockUpd()--SimClock: ' + str(round(self.simClock, 2)))
        
        print('clockUpd()--SimClock: ' + str(round(self.simClock, 2)) 
              + " nextArrTime: " + str(round(self.nextArrTime, 2))
              + " nextDeptTime: " + str(round(self.nextDeptTime, 2)))        
            
    
    # 随机数生成（时间间隔）
    def expRand(self, mean):
        
        # 基于import模块rando，生成均匀分布随机数
        r = random.uniform(0, 1)
        
        # 返回负指数分布随机数
        return - mean * math.log(r)
    
    # 到达函数    
    def arrive(self):
        
        # print("New person arrived!")
        
        self.personID += 1
        newPerson = Person(self.simClock, self.personID)
        # 加入排队队列
        self.queueList.append(newPerson)       
        
        # 查看是设备是否空闲，忙则排队
        if (self.serverStatus == 0):
            
            # print('New person is serving!')
            
            # 设备空闲，则马上服务
            self.serverStatus = 1
            # 关键：设置新的depart时间
            self.nextDeptTime = self.simClock + self.expRand(self.servMean)
            print("arrive()--Begin serving--set nextDeptTime: " 
                  + str(round(self.nextDeptTime, 2)))
            
            # person进入服务状态
            newPerson.status = 2
            newPerson.serviceBeginTime = self.simClock
                    
        # 生成下一个新到达时间
        self.nextArrTime += self.expRand(self.arrMean)
        print("arrive()--set nextArrTime: " 
                  + str(round(self.nextArrTime, 2)))

    # 离开（服务完毕）函数    
    def depart(self):
        
        # print('A person depart!')
        
        # 服务完毕
        deptPerson = self.queueList.pop(0)
        # 设为离开状态
        deptPerson.status = 3
        deptPerson.departTime = self.simClock
                
        # 加入离开队列
        self.deptList.append(deptPerson)

        # 安排下一个服务
        if(len(self.queueList) == 0):
            
            # 如果没有人排队，设备设为空闲
            self.serverStatus = 0
            # 无人准备离开，恢复nextDeptTime为最大值
            self.nextDeptTime = 9999999
            print("depart()--The queue is empty, RESET nextDeptTime: " 
                  + str(round(self.nextDeptTime, 2)))
        
        else:
            # 下一个服务
            servPerson = self.queueList[0]
            servPerson.status = 2
            servPerson.serviceBeginTime = self.simClock
            # 设备设为忙
            self.serverStatus = 1
            # 生成下一个新离开时间
            self.nextDeptTime += self.expRand(self.servMean)
            print("depart(): " + str(len(self.queueList)) 
                  + " persons in the queue!")
            print("And set nextDeptTime: " 
                  + str(round(self.nextDeptTime, 2)))
        
    # 统计更新函数，离开事件才能触发！
    def statUpd(self):
        
        # 判断是否无人离开
        if (len(self.deptList) == 0):
            print('No one depart.')
        
        else:
            # 排队时间累计更新
            self.delayTimeAccm += (self.deptList[-1].serviceBeginTime
                                   - self.deptList[-1].arriveTime)
            
            # 设备繁忙时间累计更新
            self.servTimeAccum += (self.deptList[-1].departTime
                                   - self.deptList[-1].serviceBeginTime)
            
            # 累计总时间（含等待时间与服务时间）更新
            self.totalTimeAccm += (self.deptList[-1].departTime
                                   - self.deptList[-1].arriveTime)
    
    
    # 报告生成函数
    def report(self):
        print('')
        print('==================== Simulation  Report ====================')
        
        print('')
        print('==================== Persons Information ====================')
        for i in range(len(self.deptList)):
            print('Person ID: ' + str(self.deptList[i].pID)
                  + '! Arrive Time: ' 
                  + str(round(self.deptList[i].arriveTime,2)) 
                  + '! Start Service Time: ' 
                  + str(round(self.deptList[i].serviceBeginTime,2))
                  + '! Depart Time: ' 
                  + str(round(self.deptList[i].departTime,2))) 
       
        print('')
        print('==================== System Statistics ====================')
        print('M/M/1 仿真')
        print('仿真人数：' + str(round(self.personID, 2)))
        print('到达平均间隔时间：' + str(round(self.arrMean, 2)))
        print('服务平均时间：' + str(round(self.servMean, 2)))
        
        print('')
        print('仿真运行时间：' 
              + str(round(self.simClock, 2)))
        print('总排队时间（delay）：' 
              + str(round(self.delayTimeAccm, 2)))
        print('总服务时间：' 
              + str(round(self.totalTimeAccm, 2)))
        print('设备繁忙累计时间（serving）：' 
              + str(round(self.servTimeAccum, 2)))
        
        print('')
        print('平均排队时间：' 
              + str(round(self.delayTimeAccm / self.personID, 2)))
        print('平均服务时间：' 
              + str(round(self.totalTimeAccm / self.personID, 2)))
        print('设备使用率：' 
              + str(round(self.servTimeAccum / self.simClock, 2)))
        print('平均排队人数：' 
              + str(round(self.delayTimeAccm / self.simClock, 2)))
        
        return
    

# 主函数
def main():
    
    # 仿真次数
    num_queuer = 1000
    arriveMean = 1.0
    serviceMean = 0.5
        
    # 创建QueueSim对象
    qs = QueueSim()
    
    # 仿真初始化
    qs.initialize(num_queuer, arriveMean, serviceMean)
    
    print("Welcome! The simulation begin: Testing " 
          + str(num_queuer) + " persons!")
    print('')
    print('==================== Simulation  LOG ====================')
    print('')
    
    # 仿真循环，设置仿真终止条件
    while(qs.isFinished() == False):
        
        qs.clockUpd()
                
        # 时间步进，调度arrive与depart事件
        if(qs.simClock == qs.nextArrTime):        
            qs.arrive()
        else:
            qs.depart()
            
            # 仿真统计更新
            qs.statUpd()
    
    else:
        print("The Queue Simulation FHINSHED! THANK YOU!")
        qs.report()
                
    return

if __name__ == '__main__':
    main()
# Out:
# Simulation initialize()--nextArrTime: 1.25 nextDeptTime: 999999
# Welcome! The simulation begin: Testing 1000 persons!
#
# ==================== Simulation  LOG ====================
#
# clockUpd()--SimClock: 1.25 nextArrTime: 1.25 nextDeptTime: 999999
# arrive()--Begin serving--set nextDeptTime: 1.59
# arrive()--set nextArrTime: 1.64
# clockUpd()--SimClock: 1.59 nextArrTime: 1.64 nextDeptTime: 1.59
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 1.64 nextArrTime: 1.64 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 2.08
# arrive()--set nextArrTime: 3.42
# clockUpd()--SimClock: 2.08 nextArrTime: 3.42 nextDeptTime: 2.08
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 3.42 nextArrTime: 3.42 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 3.69
# arrive()--set nextArrTime: 3.93
# clockUpd()--SimClock: 3.69 nextArrTime: 3.93 nextDeptTime: 3.69
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 3.93 nextArrTime: 3.93 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 4.18
# arrive()--set nextArrTime: 4.97
# clockUpd()--SimClock: 4.18 nextArrTime: 4.97 nextDeptTime: 4.18
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 4.97 nextArrTime: 4.97 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 5.38
# arrive()--set nextArrTime: 4.99
# clockUpd()--SimClock: 4.99 nextArrTime: 4.99 nextDeptTime: 5.38
# arrive()--set nextArrTime: 5.23
# clockUpd()--SimClock: 5.23 nextArrTime: 5.23 nextDeptTime: 5.38
# arrive()--set nextArrTime: 5.55
# clockUpd()--SimClock: 5.38 nextArrTime: 5.55 nextDeptTime: 5.38
# depart(): 2 persons in the queue!
# And set nextDeptTime: 5.54
# clockUpd()--SimClock: 5.54 nextArrTime: 5.55 nextDeptTime: 5.54
# depart(): 1 persons in the queue!
# And set nextDeptTime: 6.92
# clockUpd()--SimClock: 5.55 nextArrTime: 5.55 nextDeptTime: 6.92
# arrive()--set nextArrTime: 6.64
# clockUpd()--SimClock: 6.64 nextArrTime: 6.64 nextDeptTime: 6.92
# arrive()--set nextArrTime: 7.14
# clockUpd()--SimClock: 6.92 nextArrTime: 7.14 nextDeptTime: 6.92
# depart(): 2 persons in the queue!
# And set nextDeptTime: 8.31
# clockUpd()--SimClock: 7.14 nextArrTime: 7.14 nextDeptTime: 8.31
# arrive()--set nextArrTime: 8.79
# clockUpd()--SimClock: 8.31 nextArrTime: 8.79 nextDeptTime: 8.31
# depart(): 2 persons in the queue!
# And set nextDeptTime: 8.56
# clockUpd()--SimClock: 8.56 nextArrTime: 8.79 nextDeptTime: 8.56
# depart(): 1 persons in the queue!
# And set nextDeptTime: 8.84
# clockUpd()--SimClock: 8.79 nextArrTime: 8.79 nextDeptTime: 8.84
# arrive()--set nextArrTime: 9.38
# clockUpd()--SimClock: 8.84 nextArrTime: 9.38 nextDeptTime: 8.84
# depart(): 1 persons in the queue!
# And set nextDeptTime: 9.51
# clockUpd()--SimClock: 9.38 nextArrTime: 9.38 nextDeptTime: 9.51
# arrive()--set nextArrTime: 10.19
# clockUpd()--SimClock: 9.51 nextArrTime: 10.19 nextDeptTime: 9.51
# depart(): 1 persons in the queue!
# And set nextDeptTime: 11.31
# clockUpd()--SimClock: 10.19 nextArrTime: 10.19 nextDeptTime: 11.31
# arrive()--set nextArrTime: 12.38
# clockUpd()--SimClock: 11.31 nextArrTime: 12.38 nextDeptTime: 11.31
# depart(): 1 persons in the queue!
# And set nextDeptTime: 11.42
# clockUpd()--SimClock: 11.42 nextArrTime: 12.38 nextDeptTime: 11.42
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 12.38 nextArrTime: 12.38 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 12.46
# arrive()--set nextArrTime: 13.93
# clockUpd()--SimClock: 12.46 nextArrTime: 13.93 nextDeptTime: 12.46
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 13.93 nextArrTime: 13.93 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 13.95
# arrive()--set nextArrTime: 14.22
# clockUpd()--SimClock: 13.95 nextArrTime: 14.22 nextDeptTime: 13.95
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 14.22 nextArrTime: 14.22 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 14.36
# arrive()--set nextArrTime: 16.43
# clockUpd()--SimClock: 14.36 nextArrTime: 16.43 nextDeptTime: 14.36
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 16.43 nextArrTime: 16.43 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 16.63
# arrive()--set nextArrTime: 17.41
# clockUpd()--SimClock: 16.63 nextArrTime: 17.41 nextDeptTime: 16.63
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 17.41 nextArrTime: 17.41 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 18.17
# arrive()--set nextArrTime: 18.63
# clockUpd()--SimClock: 18.17 nextArrTime: 18.63 nextDeptTime: 18.17
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 18.63 nextArrTime: 18.63 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 18.97
# arrive()--set nextArrTime: 21.12
# clockUpd()--SimClock: 18.97 nextArrTime: 21.12 nextDeptTime: 18.97
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 21.12 nextArrTime: 21.12 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 21.52
# arrive()--set nextArrTime: 22.2
# clockUpd()--SimClock: 21.52 nextArrTime: 22.2 nextDeptTime: 21.52
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 22.2 nextArrTime: 22.2 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 22.41
# arrive()--set nextArrTime: 22.37
# clockUpd()--SimClock: 22.37 nextArrTime: 22.37 nextDeptTime: 22.41
# arrive()--set nextArrTime: 23.42
# clockUpd()--SimClock: 22.41 nextArrTime: 23.42 nextDeptTime: 22.41
# depart(): 1 persons in the queue!
# And set nextDeptTime: 23.57
# clockUpd()--SimClock: 23.42 nextArrTime: 23.42 nextDeptTime: 23.57
# arrive()--set nextArrTime: 24.19
# clockUpd()--SimClock: 23.57 nextArrTime: 24.19 nextDeptTime: 23.57
# depart(): 1 persons in the queue!
# And set nextDeptTime: 23.79
# clockUpd()--SimClock: 23.79 nextArrTime: 24.19 nextDeptTime: 23.79
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 24.19 nextArrTime: 24.19 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 25.34
# arrive()--set nextArrTime: 26.1
# clockUpd()--SimClock: 25.34 nextArrTime: 26.1 nextDeptTime: 25.34
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 26.1 nextArrTime: 26.1 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 27.95
# arrive()--set nextArrTime: 27.67
# clockUpd()--SimClock: 27.67 nextArrTime: 27.67 nextDeptTime: 27.95
# arrive()--set nextArrTime: 29.5
# clockUpd()--SimClock: 27.95 nextArrTime: 29.5 nextDeptTime: 27.95
# depart(): 1 persons in the queue!
# And set nextDeptTime: 28.16
# clockUpd()--SimClock: 28.16 nextArrTime: 29.5 nextDeptTime: 28.16
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 29.5 nextArrTime: 29.5 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 29.54
# arrive()--set nextArrTime: 29.68
# clockUpd()--SimClock: 29.54 nextArrTime: 29.68 nextDeptTime: 29.54
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 29.68 nextArrTime: 29.68 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 30.16
# arrive()--set nextArrTime: 29.74
# clockUpd()--SimClock: 29.74 nextArrTime: 29.74 nextDeptTime: 30.16
# arrive()--set nextArrTime: 30.65
# clockUpd()--SimClock: 30.16 nextArrTime: 30.65 nextDeptTime: 30.16
# depart(): 1 persons in the queue!
# And set nextDeptTime: 30.18
# clockUpd()--SimClock: 30.18 nextArrTime: 30.65 nextDeptTime: 30.18
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 30.65 nextArrTime: 30.65 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 30.88
# arrive()--set nextArrTime: 31.95
# clockUpd()--SimClock: 30.88 nextArrTime: 31.95 nextDeptTime: 30.88
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 31.95 nextArrTime: 31.95 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 31.99
# arrive()--set nextArrTime: 32.68
# clockUpd()--SimClock: 31.99 nextArrTime: 32.68 nextDeptTime: 31.99
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 32.68 nextArrTime: 32.68 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 33.26
# arrive()--set nextArrTime: 32.85
# clockUpd()--SimClock: 32.85 nextArrTime: 32.85 nextDeptTime: 33.26
# arrive()--set nextArrTime: 34.01
# clockUpd()--SimClock: 33.26 nextArrTime: 34.01 nextDeptTime: 33.26
# depart(): 1 persons in the queue!
# And set nextDeptTime: 35.37
# clockUpd()--SimClock: 34.01 nextArrTime: 34.01 nextDeptTime: 35.37
# arrive()--set nextArrTime: 35.39
# clockUpd()--SimClock: 35.37 nextArrTime: 35.39 nextDeptTime: 35.37
# depart(): 1 persons in the queue!
# And set nextDeptTime: 35.55
# clockUpd()--SimClock: 35.39 nextArrTime: 35.39 nextDeptTime: 35.55
# arrive()--set nextArrTime: 36.24
# clockUpd()--SimClock: 35.55 nextArrTime: 36.24 nextDeptTime: 35.55
# depart(): 1 persons in the queue!
# And set nextDeptTime: 35.76
# clockUpd()--SimClock: 35.76 nextArrTime: 36.24 nextDeptTime: 35.76
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 36.24 nextArrTime: 36.24 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 37.51
# arrive()--set nextArrTime: 38.7
# clockUpd()--SimClock: 37.51 nextArrTime: 38.7 nextDeptTime: 37.51
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 38.7 nextArrTime: 38.7 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 38.7
# arrive()--set nextArrTime: 38.78
# clockUpd()--SimClock: 38.7 nextArrTime: 38.78 nextDeptTime: 38.7
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 38.78 nextArrTime: 38.78 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 39.04
# arrive()--set nextArrTime: 38.93
# clockUpd()--SimClock: 38.93 nextArrTime: 38.93 nextDeptTime: 39.04
# arrive()--set nextArrTime: 40.29
# clockUpd()--SimClock: 39.04 nextArrTime: 40.29 nextDeptTime: 39.04
# depart(): 1 persons in the queue!
# And set nextDeptTime: 39.34
# clockUpd()--SimClock: 39.34 nextArrTime: 40.29 nextDeptTime: 39.34
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 40.29 nextArrTime: 40.29 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 40.97
# arrive()--set nextArrTime: 40.91
# clockUpd()--SimClock: 40.91 nextArrTime: 40.91 nextDeptTime: 40.97
# arrive()--set nextArrTime: 41.27
# clockUpd()--SimClock: 40.97 nextArrTime: 41.27 nextDeptTime: 40.97
# depart(): 1 persons in the queue!
# And set nextDeptTime: 42.22
# clockUpd()--SimClock: 41.27 nextArrTime: 41.27 nextDeptTime: 42.22
# arrive()--set nextArrTime: 41.58
# clockUpd()--SimClock: 41.58 nextArrTime: 41.58 nextDeptTime: 42.22
# arrive()--set nextArrTime: 41.77
# clockUpd()--SimClock: 41.77 nextArrTime: 41.77 nextDeptTime: 42.22
# arrive()--set nextArrTime: 43.41
# clockUpd()--SimClock: 42.22 nextArrTime: 43.41 nextDeptTime: 42.22
# depart(): 3 persons in the queue!
# And set nextDeptTime: 42.78
# clockUpd()--SimClock: 42.78 nextArrTime: 43.41 nextDeptTime: 42.78
# depart(): 2 persons in the queue!
# And set nextDeptTime: 43.12
# clockUpd()--SimClock: 43.12 nextArrTime: 43.41 nextDeptTime: 43.12
# depart(): 1 persons in the queue!
# And set nextDeptTime: 43.27
# clockUpd()--SimClock: 43.27 nextArrTime: 43.41 nextDeptTime: 43.27
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 43.41 nextArrTime: 43.41 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 43.72
# arrive()--set nextArrTime: 44.09
# clockUpd()--SimClock: 43.72 nextArrTime: 44.09 nextDeptTime: 43.72
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 44.09 nextArrTime: 44.09 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 44.43
# arrive()--set nextArrTime: 44.87
# clockUpd()--SimClock: 44.43 nextArrTime: 44.87 nextDeptTime: 44.43
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 44.87 nextArrTime: 44.87 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 45.26
# arrive()--set nextArrTime: 44.99
# clockUpd()--SimClock: 44.99 nextArrTime: 44.99 nextDeptTime: 45.26
# arrive()--set nextArrTime: 45.59
# clockUpd()--SimClock: 45.26 nextArrTime: 45.59 nextDeptTime: 45.26
# depart(): 1 persons in the queue!
# And set nextDeptTime: 45.41
# clockUpd()--SimClock: 45.41 nextArrTime: 45.59 nextDeptTime: 45.41
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 45.59 nextArrTime: 45.59 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 45.79
# arrive()--set nextArrTime: 45.75
# clockUpd()--SimClock: 45.75 nextArrTime: 45.75 nextDeptTime: 45.79
# arrive()--set nextArrTime: 49.66
# clockUpd()--SimClock: 45.79 nextArrTime: 49.66 nextDeptTime: 45.79
# depart(): 1 persons in the queue!
# And set nextDeptTime: 45.86
# clockUpd()--SimClock: 45.86 nextArrTime: 49.66 nextDeptTime: 45.86
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 49.66 nextArrTime: 49.66 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 50.06
# arrive()--set nextArrTime: 49.77
# clockUpd()--SimClock: 49.77 nextArrTime: 49.77 nextDeptTime: 50.06
# arrive()--set nextArrTime: 49.97
# clockUpd()--SimClock: 49.97 nextArrTime: 49.97 nextDeptTime: 50.06
# arrive()--set nextArrTime: 52.48
# clockUpd()--SimClock: 50.06 nextArrTime: 52.48 nextDeptTime: 50.06
# depart(): 2 persons in the queue!
# And set nextDeptTime: 50.48
# clockUpd()--SimClock: 50.48 nextArrTime: 52.48 nextDeptTime: 50.48
# depart(): 1 persons in the queue!
# And set nextDeptTime: 50.61
# clockUpd()--SimClock: 50.61 nextArrTime: 52.48 nextDeptTime: 50.61
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 52.48 nextArrTime: 52.48 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 52.72
# arrive()--set nextArrTime: 53.42
# clockUpd()--SimClock: 52.72 nextArrTime: 53.42 nextDeptTime: 52.72
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 53.42 nextArrTime: 53.42 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 54.16
# arrive()--set nextArrTime: 56.02
# clockUpd()--SimClock: 54.16 nextArrTime: 56.02 nextDeptTime: 54.16
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 56.02 nextArrTime: 56.02 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 56.05
# arrive()--set nextArrTime: 57.28
# clockUpd()--SimClock: 56.05 nextArrTime: 57.28 nextDeptTime: 56.05
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 57.28 nextArrTime: 57.28 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 57.44
# arrive()--set nextArrTime: 60.09
# clockUpd()--SimClock: 57.44 nextArrTime: 60.09 nextDeptTime: 57.44
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 60.09 nextArrTime: 60.09 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 60.21
# arrive()--set nextArrTime: 65.42
# clockUpd()--SimClock: 60.21 nextArrTime: 65.42 nextDeptTime: 60.21
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 65.42 nextArrTime: 65.42 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 66.19
# arrive()--set nextArrTime: 65.73
# clockUpd()--SimClock: 65.73 nextArrTime: 65.73 nextDeptTime: 66.19
# arrive()--set nextArrTime: 66.22
# clockUpd()--SimClock: 66.19 nextArrTime: 66.22 nextDeptTime: 66.19
# depart(): 1 persons in the queue!
# And set nextDeptTime: 66.47
# clockUpd()--SimClock: 66.22 nextArrTime: 66.22 nextDeptTime: 66.47
# arrive()--set nextArrTime: 66.93
# clockUpd()--SimClock: 66.47 nextArrTime: 66.93 nextDeptTime: 66.47
# depart(): 1 persons in the queue!
# And set nextDeptTime: 66.76
# clockUpd()--SimClock: 66.76 nextArrTime: 66.93 nextDeptTime: 66.76
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 66.93 nextArrTime: 66.93 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 66.99
# arrive()--set nextArrTime: 68.25
# clockUpd()--SimClock: 66.99 nextArrTime: 68.25 nextDeptTime: 66.99
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 68.25 nextArrTime: 68.25 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 69.03
# arrive()--set nextArrTime: 70.2
# clockUpd()--SimClock: 69.03 nextArrTime: 70.2 nextDeptTime: 69.03
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 70.2 nextArrTime: 70.2 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 70.39
# arrive()--set nextArrTime: 71.41
# clockUpd()--SimClock: 70.39 nextArrTime: 71.41 nextDeptTime: 70.39
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 71.41 nextArrTime: 71.41 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 71.41
# arrive()--set nextArrTime: 76.48
# clockUpd()--SimClock: 71.41 nextArrTime: 76.48 nextDeptTime: 71.41
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 76.48 nextArrTime: 76.48 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 76.75
# arrive()--set nextArrTime: 77.96
# clockUpd()--SimClock: 76.75 nextArrTime: 77.96 nextDeptTime: 76.75
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 77.96 nextArrTime: 77.96 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 78.84
# arrive()--set nextArrTime: 77.97
# clockUpd()--SimClock: 77.97 nextArrTime: 77.97 nextDeptTime: 78.84
# arrive()--set nextArrTime: 78.53
# clockUpd()--SimClock: 78.53 nextArrTime: 78.53 nextDeptTime: 78.84
# arrive()--set nextArrTime: 78.68
# clockUpd()--SimClock: 78.68 nextArrTime: 78.68 nextDeptTime: 78.84
# arrive()--set nextArrTime: 78.94
# clockUpd()--SimClock: 78.84 nextArrTime: 78.94 nextDeptTime: 78.84
# depart(): 3 persons in the queue!
# And set nextDeptTime: 79.27
# clockUpd()--SimClock: 78.94 nextArrTime: 78.94 nextDeptTime: 79.27
# arrive()--set nextArrTime: 79.04
# clockUpd()--SimClock: 79.04 nextArrTime: 79.04 nextDeptTime: 79.27
# arrive()--set nextArrTime: 79.1
# clockUpd()--SimClock: 79.1 nextArrTime: 79.1 nextDeptTime: 79.27
# arrive()--set nextArrTime: 79.6
# clockUpd()--SimClock: 79.27 nextArrTime: 79.6 nextDeptTime: 79.27
# depart(): 5 persons in the queue!
# And set nextDeptTime: 79.67
# clockUpd()--SimClock: 79.6 nextArrTime: 79.6 nextDeptTime: 79.67
# arrive()--set nextArrTime: 81.41
# clockUpd()--SimClock: 79.67 nextArrTime: 81.41 nextDeptTime: 79.67
# depart(): 5 persons in the queue!
# And set nextDeptTime: 79.86
# clockUpd()--SimClock: 79.86 nextArrTime: 81.41 nextDeptTime: 79.86
# depart(): 4 persons in the queue!
# And set nextDeptTime: 80.05
# clockUpd()--SimClock: 80.05 nextArrTime: 81.41 nextDeptTime: 80.05
# depart(): 3 persons in the queue!
# And set nextDeptTime: 80.37
# clockUpd()--SimClock: 80.37 nextArrTime: 81.41 nextDeptTime: 80.37
# depart(): 2 persons in the queue!
# And set nextDeptTime: 80.74
# clockUpd()--SimClock: 80.74 nextArrTime: 81.41 nextDeptTime: 80.74
# depart(): 1 persons in the queue!
# And set nextDeptTime: 81.17
# clockUpd()--SimClock: 81.17 nextArrTime: 81.41 nextDeptTime: 81.17
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 81.41 nextArrTime: 81.41 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 82.35
# arrive()--set nextArrTime: 82.03
# clockUpd()--SimClock: 82.03 nextArrTime: 82.03 nextDeptTime: 82.35
# arrive()--set nextArrTime: 82.59
# clockUpd()--SimClock: 82.35 nextArrTime: 82.59 nextDeptTime: 82.35
# depart(): 1 persons in the queue!
# And set nextDeptTime: 83.65
# clockUpd()--SimClock: 82.59 nextArrTime: 82.59 nextDeptTime: 83.65
# arrive()--set nextArrTime: 82.83
# clockUpd()--SimClock: 82.83 nextArrTime: 82.83 nextDeptTime: 83.65
# arrive()--set nextArrTime: 83.3
# clockUpd()--SimClock: 83.3 nextArrTime: 83.3 nextDeptTime: 83.65
# arrive()--set nextArrTime: 83.97
# clockUpd()--SimClock: 83.65 nextArrTime: 83.97 nextDeptTime: 83.65
# depart(): 3 persons in the queue!
# And set nextDeptTime: 84.4
# clockUpd()--SimClock: 83.97 nextArrTime: 83.97 nextDeptTime: 84.4
# arrive()--set nextArrTime: 85.78
# clockUpd()--SimClock: 84.4 nextArrTime: 85.78 nextDeptTime: 84.4
# depart(): 3 persons in the queue!
# And set nextDeptTime: 84.84
# clockUpd()--SimClock: 84.84 nextArrTime: 85.78 nextDeptTime: 84.84
# depart(): 2 persons in the queue!
# And set nextDeptTime: 85.71
# clockUpd()--SimClock: 85.71 nextArrTime: 85.78 nextDeptTime: 85.71
# depart(): 1 persons in the queue!
# And set nextDeptTime: 85.81
# clockUpd()--SimClock: 85.78 nextArrTime: 85.78 nextDeptTime: 85.81
# arrive()--set nextArrTime: 87.25
# clockUpd()--SimClock: 85.81 nextArrTime: 87.25 nextDeptTime: 85.81
# depart(): 1 persons in the queue!
# And set nextDeptTime: 85.97
# clockUpd()--SimClock: 85.97 nextArrTime: 87.25 nextDeptTime: 85.97
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 87.25 nextArrTime: 87.25 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 87.31
# arrive()--set nextArrTime: 87.6
# clockUpd()--SimClock: 87.31 nextArrTime: 87.6 nextDeptTime: 87.31
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 87.6 nextArrTime: 87.6 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 87.67
# arrive()--set nextArrTime: 87.61
# clockUpd()--SimClock: 87.61 nextArrTime: 87.61 nextDeptTime: 87.67
# arrive()--set nextArrTime: 88.11
# clockUpd()--SimClock: 87.67 nextArrTime: 88.11 nextDeptTime: 87.67
# depart(): 1 persons in the queue!
# And set nextDeptTime: 87.84
# clockUpd()--SimClock: 87.84 nextArrTime: 88.11 nextDeptTime: 87.84
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 88.11 nextArrTime: 88.11 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 88.6
# arrive()--set nextArrTime: 88.76
# clockUpd()--SimClock: 88.6 nextArrTime: 88.76 nextDeptTime: 88.6
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 88.76 nextArrTime: 88.76 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 88.77
# arrive()--set nextArrTime: 91.73
# clockUpd()--SimClock: 88.77 nextArrTime: 91.73 nextDeptTime: 88.77
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 91.73 nextArrTime: 91.73 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 92.52
# arrive()--set nextArrTime: 92.71
# clockUpd()--SimClock: 92.52 nextArrTime: 92.71 nextDeptTime: 92.52
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 92.71 nextArrTime: 92.71 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 92.97
# arrive()--set nextArrTime: 93.22
# clockUpd()--SimClock: 92.97 nextArrTime: 93.22 nextDeptTime: 92.97
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 93.22 nextArrTime: 93.22 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 93.44
# arrive()--set nextArrTime: 94.05
# clockUpd()--SimClock: 93.44 nextArrTime: 94.05 nextDeptTime: 93.44
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 94.05 nextArrTime: 94.05 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 94.35
# arrive()--set nextArrTime: 95.71
# clockUpd()--SimClock: 94.35 nextArrTime: 95.71 nextDeptTime: 94.35
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 95.71 nextArrTime: 95.71 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 96.42
# arrive()--set nextArrTime: 95.99
# clockUpd()--SimClock: 95.99 nextArrTime: 95.99 nextDeptTime: 96.42
# arrive()--set nextArrTime: 96.25
# clockUpd()--SimClock: 96.25 nextArrTime: 96.25 nextDeptTime: 96.42
# arrive()--set nextArrTime: 97.48
# clockUpd()--SimClock: 96.42 nextArrTime: 97.48 nextDeptTime: 96.42
# depart(): 2 persons in the queue!
# And set nextDeptTime: 97.77
# clockUpd()--SimClock: 97.48 nextArrTime: 97.48 nextDeptTime: 97.77
# arrive()--set nextArrTime: 98.03
# clockUpd()--SimClock: 97.77 nextArrTime: 98.03 nextDeptTime: 97.77
# depart(): 2 persons in the queue!
# And set nextDeptTime: 98.22
# clockUpd()--SimClock: 98.03 nextArrTime: 98.03 nextDeptTime: 98.22
# arrive()--set nextArrTime: 98.27
# clockUpd()--SimClock: 98.22 nextArrTime: 98.27 nextDeptTime: 98.22
# depart(): 2 persons in the queue!
# And set nextDeptTime: 99.99
# clockUpd()--SimClock: 98.27 nextArrTime: 98.27 nextDeptTime: 99.99
# arrive()--set nextArrTime: 98.29
# clockUpd()--SimClock: 98.29 nextArrTime: 98.29 nextDeptTime: 99.99
# arrive()--set nextArrTime: 99.73
# clockUpd()--SimClock: 99.73 nextArrTime: 99.73 nextDeptTime: 99.99
# arrive()--set nextArrTime: 100.38
# clockUpd()--SimClock: 99.99 nextArrTime: 100.38 nextDeptTime: 99.99
# depart(): 4 persons in the queue!
# And set nextDeptTime: 100.02
# clockUpd()--SimClock: 100.02 nextArrTime: 100.38 nextDeptTime: 100.02
# depart(): 3 persons in the queue!
# And set nextDeptTime: 100.46
# clockUpd()--SimClock: 100.38 nextArrTime: 100.38 nextDeptTime: 100.46
# arrive()--set nextArrTime: 101.26
# clockUpd()--SimClock: 100.46 nextArrTime: 101.26 nextDeptTime: 100.46
# depart(): 3 persons in the queue!
# And set nextDeptTime: 100.75
# clockUpd()--SimClock: 100.75 nextArrTime: 101.26 nextDeptTime: 100.75
# depart(): 2 persons in the queue!
# And set nextDeptTime: 101.14
# clockUpd()--SimClock: 101.14 nextArrTime: 101.26 nextDeptTime: 101.14
# depart(): 1 persons in the queue!
# And set nextDeptTime: 101.35
# clockUpd()--SimClock: 101.26 nextArrTime: 101.26 nextDeptTime: 101.35
# arrive()--set nextArrTime: 103.0
# clockUpd()--SimClock: 101.35 nextArrTime: 103.0 nextDeptTime: 101.35
# depart(): 1 persons in the queue!
# And set nextDeptTime: 101.62
# clockUpd()--SimClock: 101.62 nextArrTime: 103.0 nextDeptTime: 101.62
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 103.0 nextArrTime: 103.0 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 103.41
# arrive()--set nextArrTime: 104.92
# clockUpd()--SimClock: 103.41 nextArrTime: 104.92 nextDeptTime: 103.41
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 104.92 nextArrTime: 104.92 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 105.11
# arrive()--set nextArrTime: 104.95
# clockUpd()--SimClock: 104.95 nextArrTime: 104.95 nextDeptTime: 105.11
# arrive()--set nextArrTime: 105.23
# clockUpd()--SimClock: 105.11 nextArrTime: 105.23 nextDeptTime: 105.11
# depart(): 1 persons in the queue!
# And set nextDeptTime: 106.19
# clockUpd()--SimClock: 105.23 nextArrTime: 105.23 nextDeptTime: 106.19
# arrive()--set nextArrTime: 105.26
# clockUpd()--SimClock: 105.26 nextArrTime: 105.26 nextDeptTime: 106.19
# arrive()--set nextArrTime: 107.52
# clockUpd()--SimClock: 106.19 nextArrTime: 107.52 nextDeptTime: 106.19
# depart(): 2 persons in the queue!
# And set nextDeptTime: 106.84
# clockUpd()--SimClock: 106.84 nextArrTime: 107.52 nextDeptTime: 106.84
# depart(): 1 persons in the queue!
# And set nextDeptTime: 106.95
# clockUpd()--SimClock: 106.95 nextArrTime: 107.52 nextDeptTime: 106.95
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 107.52 nextArrTime: 107.52 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 108.65
# arrive()--set nextArrTime: 107.79
# clockUpd()--SimClock: 107.79 nextArrTime: 107.79 nextDeptTime: 108.65
# arrive()--set nextArrTime: 109.87
# clockUpd()--SimClock: 108.65 nextArrTime: 109.87 nextDeptTime: 108.65
# depart(): 1 persons in the queue!
# And set nextDeptTime: 109.33
# clockUpd()--SimClock: 109.33 nextArrTime: 109.87 nextDeptTime: 109.33
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 109.87 nextArrTime: 109.87 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 110.13
# arrive()--set nextArrTime: 110.55
# clockUpd()--SimClock: 110.13 nextArrTime: 110.55 nextDeptTime: 110.13
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 110.55 nextArrTime: 110.55 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 110.62
# arrive()--set nextArrTime: 111.52
# clockUpd()--SimClock: 110.62 nextArrTime: 111.52 nextDeptTime: 110.62
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 111.52 nextArrTime: 111.52 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 111.92
# arrive()--set nextArrTime: 114.73
# clockUpd()--SimClock: 111.92 nextArrTime: 114.73 nextDeptTime: 111.92
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 114.73 nextArrTime: 114.73 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 114.74
# arrive()--set nextArrTime: 119.32
# clockUpd()--SimClock: 114.74 nextArrTime: 119.32 nextDeptTime: 114.74
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 119.32 nextArrTime: 119.32 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 120.22
# arrive()--set nextArrTime: 120.67
# clockUpd()--SimClock: 120.22 nextArrTime: 120.67 nextDeptTime: 120.22
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 120.67 nextArrTime: 120.67 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 120.96
# arrive()--set nextArrTime: 120.73
# clockUpd()--SimClock: 120.73 nextArrTime: 120.73 nextDeptTime: 120.96
# arrive()--set nextArrTime: 121.35
# clockUpd()--SimClock: 120.96 nextArrTime: 121.35 nextDeptTime: 120.96
# depart(): 1 persons in the queue!
# And set nextDeptTime: 121.13
# clockUpd()--SimClock: 121.13 nextArrTime: 121.35 nextDeptTime: 121.13
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 121.35 nextArrTime: 121.35 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 122.54
# arrive()--set nextArrTime: 121.39
# clockUpd()--SimClock: 121.39 nextArrTime: 121.39 nextDeptTime: 122.54
# arrive()--set nextArrTime: 122.36
# clockUpd()--SimClock: 122.36 nextArrTime: 122.36 nextDeptTime: 122.54
# arrive()--set nextArrTime: 122.64
# clockUpd()--SimClock: 122.54 nextArrTime: 122.64 nextDeptTime: 122.54
# depart(): 2 persons in the queue!
# And set nextDeptTime: 123.05
# clockUpd()--SimClock: 122.64 nextArrTime: 122.64 nextDeptTime: 123.05
# arrive()--set nextArrTime: 125.6
# clockUpd()--SimClock: 123.05 nextArrTime: 125.6 nextDeptTime: 123.05
# depart(): 2 persons in the queue!
# And set nextDeptTime: 124.07
# clockUpd()--SimClock: 124.07 nextArrTime: 125.6 nextDeptTime: 124.07
# depart(): 1 persons in the queue!
# And set nextDeptTime: 125.12
# clockUpd()--SimClock: 125.12 nextArrTime: 125.6 nextDeptTime: 125.12
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 125.6 nextArrTime: 125.6 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 125.7
# arrive()--set nextArrTime: 125.68
# clockUpd()--SimClock: 125.68 nextArrTime: 125.68 nextDeptTime: 125.7
# arrive()--set nextArrTime: 125.93
# clockUpd()--SimClock: 125.7 nextArrTime: 125.93 nextDeptTime: 125.7
# depart(): 1 persons in the queue!
# And set nextDeptTime: 126.99
# clockUpd()--SimClock: 125.93 nextArrTime: 125.93 nextDeptTime: 126.99
# arrive()--set nextArrTime: 125.94
# clockUpd()--SimClock: 125.94 nextArrTime: 125.94 nextDeptTime: 126.99
# arrive()--set nextArrTime: 126.12
# clockUpd()--SimClock: 126.12 nextArrTime: 126.12 nextDeptTime: 126.99
# arrive()--set nextArrTime: 126.19
# clockUpd()--SimClock: 126.19 nextArrTime: 126.19 nextDeptTime: 126.99
# arrive()--set nextArrTime: 126.32
# clockUpd()--SimClock: 126.32 nextArrTime: 126.32 nextDeptTime: 126.99
# arrive()--set nextArrTime: 127.52
# clockUpd()--SimClock: 126.99 nextArrTime: 127.52 nextDeptTime: 126.99
# depart(): 5 persons in the queue!
# And set nextDeptTime: 127.77
# clockUpd()--SimClock: 127.52 nextArrTime: 127.52 nextDeptTime: 127.77
# arrive()--set nextArrTime: 128.23
# clockUpd()--SimClock: 127.77 nextArrTime: 128.23 nextDeptTime: 127.77
# depart(): 5 persons in the queue!
# And set nextDeptTime: 127.82
# clockUpd()--SimClock: 127.82 nextArrTime: 128.23 nextDeptTime: 127.82
# depart(): 4 persons in the queue!
# And set nextDeptTime: 128.14
# clockUpd()--SimClock: 128.14 nextArrTime: 128.23 nextDeptTime: 128.14
# depart(): 3 persons in the queue!
# And set nextDeptTime: 128.42
# clockUpd()--SimClock: 128.23 nextArrTime: 128.23 nextDeptTime: 128.42
# arrive()--set nextArrTime: 129.31
# clockUpd()--SimClock: 128.42 nextArrTime: 129.31 nextDeptTime: 128.42
# depart(): 3 persons in the queue!
# And set nextDeptTime: 128.86
# clockUpd()--SimClock: 128.86 nextArrTime: 129.31 nextDeptTime: 128.86
# depart(): 2 persons in the queue!
# And set nextDeptTime: 129.55
# clockUpd()--SimClock: 129.31 nextArrTime: 129.31 nextDeptTime: 129.55
# arrive()--set nextArrTime: 129.54
# clockUpd()--SimClock: 129.54 nextArrTime: 129.54 nextDeptTime: 129.55
# arrive()--set nextArrTime: 132.53
# clockUpd()--SimClock: 129.55 nextArrTime: 132.53 nextDeptTime: 129.55
# depart(): 3 persons in the queue!
# And set nextDeptTime: 131.54
# clockUpd()--SimClock: 131.54 nextArrTime: 132.53 nextDeptTime: 131.54
# depart(): 2 persons in the queue!
# And set nextDeptTime: 132.09
# clockUpd()--SimClock: 132.09 nextArrTime: 132.53 nextDeptTime: 132.09
# depart(): 1 persons in the queue!
# And set nextDeptTime: 132.16
# clockUpd()--SimClock: 132.16 nextArrTime: 132.53 nextDeptTime: 132.16
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 132.53 nextArrTime: 132.53 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 133.07
# arrive()--set nextArrTime: 132.56
# clockUpd()--SimClock: 132.56 nextArrTime: 132.56 nextDeptTime: 133.07
# arrive()--set nextArrTime: 133.33
# clockUpd()--SimClock: 133.07 nextArrTime: 133.33 nextDeptTime: 133.07
# depart(): 1 persons in the queue!
# And set nextDeptTime: 133.13
# clockUpd()--SimClock: 133.13 nextArrTime: 133.33 nextDeptTime: 133.13
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 133.33 nextArrTime: 133.33 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 133.63
# arrive()--set nextArrTime: 133.92
# clockUpd()--SimClock: 133.63 nextArrTime: 133.92 nextDeptTime: 133.63
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 133.92 nextArrTime: 133.92 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 135.27
# arrive()--set nextArrTime: 134.95
# clockUpd()--SimClock: 134.95 nextArrTime: 134.95 nextDeptTime: 135.27
# arrive()--set nextArrTime: 135.06
# clockUpd()--SimClock: 135.06 nextArrTime: 135.06 nextDeptTime: 135.27
# arrive()--set nextArrTime: 135.51
# clockUpd()--SimClock: 135.27 nextArrTime: 135.51 nextDeptTime: 135.27
# depart(): 2 persons in the queue!
# And set nextDeptTime: 135.46
# clockUpd()--SimClock: 135.46 nextArrTime: 135.51 nextDeptTime: 135.46
# depart(): 1 persons in the queue!
# And set nextDeptTime: 135.87
# clockUpd()--SimClock: 135.51 nextArrTime: 135.51 nextDeptTime: 135.87
# arrive()--set nextArrTime: 138.2
# clockUpd()--SimClock: 135.87 nextArrTime: 138.2 nextDeptTime: 135.87
# depart(): 1 persons in the queue!
# And set nextDeptTime: 135.97
# clockUpd()--SimClock: 135.97 nextArrTime: 138.2 nextDeptTime: 135.97
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 138.2 nextArrTime: 138.2 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 139.07
# arrive()--set nextArrTime: 138.88
# clockUpd()--SimClock: 138.88 nextArrTime: 138.88 nextDeptTime: 139.07
# arrive()--set nextArrTime: 140.73
# clockUpd()--SimClock: 139.07 nextArrTime: 140.73 nextDeptTime: 139.07
# depart(): 1 persons in the queue!
# And set nextDeptTime: 139.29
# clockUpd()--SimClock: 139.29 nextArrTime: 140.73 nextDeptTime: 139.29
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 140.73 nextArrTime: 140.73 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 141.94
# arrive()--set nextArrTime: 141.0
# clockUpd()--SimClock: 141.0 nextArrTime: 141.0 nextDeptTime: 141.94
# arrive()--set nextArrTime: 142.44
# clockUpd()--SimClock: 141.94 nextArrTime: 142.44 nextDeptTime: 141.94
# depart(): 1 persons in the queue!
# And set nextDeptTime: 142.2
# clockUpd()--SimClock: 142.2 nextArrTime: 142.44 nextDeptTime: 142.2
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 142.44 nextArrTime: 142.44 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 142.71
# arrive()--set nextArrTime: 142.59
# clockUpd()--SimClock: 142.59 nextArrTime: 142.59 nextDeptTime: 142.71
# arrive()--set nextArrTime: 143.36
# clockUpd()--SimClock: 142.71 nextArrTime: 143.36 nextDeptTime: 142.71
# depart(): 1 persons in the queue!
# And set nextDeptTime: 142.79
# clockUpd()--SimClock: 142.79 nextArrTime: 143.36 nextDeptTime: 142.79
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 143.36 nextArrTime: 143.36 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 144.02
# arrive()--set nextArrTime: 144.1
# clockUpd()--SimClock: 144.02 nextArrTime: 144.1 nextDeptTime: 144.02
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 144.1 nextArrTime: 144.1 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 145.75
# arrive()--set nextArrTime: 146.09
# clockUpd()--SimClock: 145.75 nextArrTime: 146.09 nextDeptTime: 145.75
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 146.09 nextArrTime: 146.09 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 147.1
# arrive()--set nextArrTime: 146.88
# clockUpd()--SimClock: 146.88 nextArrTime: 146.88 nextDeptTime: 147.1
# arrive()--set nextArrTime: 147.13
# clockUpd()--SimClock: 147.1 nextArrTime: 147.13 nextDeptTime: 147.1
# depart(): 1 persons in the queue!
# And set nextDeptTime: 148.93
# clockUpd()--SimClock: 147.13 nextArrTime: 147.13 nextDeptTime: 148.93
# arrive()--set nextArrTime: 147.61
# clockUpd()--SimClock: 147.61 nextArrTime: 147.61 nextDeptTime: 148.93
# arrive()--set nextArrTime: 148.4
# clockUpd()--SimClock: 148.4 nextArrTime: 148.4 nextDeptTime: 148.93
# arrive()--set nextArrTime: 149.57
# clockUpd()--SimClock: 148.93 nextArrTime: 149.57 nextDeptTime: 148.93
# depart(): 3 persons in the queue!
# And set nextDeptTime: 150.11
# clockUpd()--SimClock: 149.57 nextArrTime: 149.57 nextDeptTime: 150.11
# arrive()--set nextArrTime: 150.37
# clockUpd()--SimClock: 150.11 nextArrTime: 150.37 nextDeptTime: 150.11
# depart(): 3 persons in the queue!
# And set nextDeptTime: 150.31
# clockUpd()--SimClock: 150.31 nextArrTime: 150.37 nextDeptTime: 150.31
# depart(): 2 persons in the queue!
# And set nextDeptTime: 150.6
# clockUpd()--SimClock: 150.37 nextArrTime: 150.37 nextDeptTime: 150.6
# arrive()--set nextArrTime: 150.44
# clockUpd()--SimClock: 150.44 nextArrTime: 150.44 nextDeptTime: 150.6
# arrive()--set nextArrTime: 150.46
# clockUpd()--SimClock: 150.46 nextArrTime: 150.46 nextDeptTime: 150.6
# arrive()--set nextArrTime: 152.52
# clockUpd()--SimClock: 150.6 nextArrTime: 152.52 nextDeptTime: 150.6
# depart(): 4 persons in the queue!
# And set nextDeptTime: 151.66
# clockUpd()--SimClock: 151.66 nextArrTime: 152.52 nextDeptTime: 151.66
# depart(): 3 persons in the queue!
# And set nextDeptTime: 154.45
# clockUpd()--SimClock: 152.52 nextArrTime: 152.52 nextDeptTime: 154.45
# arrive()--set nextArrTime: 153.67
# clockUpd()--SimClock: 153.67 nextArrTime: 153.67 nextDeptTime: 154.45
# arrive()--set nextArrTime: 155.07
# clockUpd()--SimClock: 154.45 nextArrTime: 155.07 nextDeptTime: 154.45
# depart(): 4 persons in the queue!
# And set nextDeptTime: 154.8
# clockUpd()--SimClock: 154.8 nextArrTime: 155.07 nextDeptTime: 154.8
# depart(): 3 persons in the queue!
# And set nextDeptTime: 154.81
# clockUpd()--SimClock: 154.81 nextArrTime: 155.07 nextDeptTime: 154.81
# depart(): 2 persons in the queue!
# And set nextDeptTime: 154.92
# clockUpd()--SimClock: 154.92 nextArrTime: 155.07 nextDeptTime: 154.92
# depart(): 1 persons in the queue!
# And set nextDeptTime: 155.09
# clockUpd()--SimClock: 155.07 nextArrTime: 155.07 nextDeptTime: 155.09
# arrive()--set nextArrTime: 155.61
# clockUpd()--SimClock: 155.09 nextArrTime: 155.61 nextDeptTime: 155.09
# depart(): 1 persons in the queue!
# And set nextDeptTime: 155.59
# clockUpd()--SimClock: 155.59 nextArrTime: 155.61 nextDeptTime: 155.59
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 155.61 nextArrTime: 155.61 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 155.65
# arrive()--set nextArrTime: 156.01
# clockUpd()--SimClock: 155.65 nextArrTime: 156.01 nextDeptTime: 155.65
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 156.01 nextArrTime: 156.01 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 157.55
# arrive()--set nextArrTime: 156.13
# clockUpd()--SimClock: 156.13 nextArrTime: 156.13 nextDeptTime: 157.55
# arrive()--set nextArrTime: 157.63
# clockUpd()--SimClock: 157.55 nextArrTime: 157.63 nextDeptTime: 157.55
# depart(): 1 persons in the queue!
# And set nextDeptTime: 157.74
# clockUpd()--SimClock: 157.63 nextArrTime: 157.63 nextDeptTime: 157.74
# arrive()--set nextArrTime: 158.16
# clockUpd()--SimClock: 157.74 nextArrTime: 158.16 nextDeptTime: 157.74
# depart(): 1 persons in the queue!
# And set nextDeptTime: 158.03
# clockUpd()--SimClock: 158.03 nextArrTime: 158.16 nextDeptTime: 158.03
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 158.16 nextArrTime: 158.16 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 158.34
# arrive()--set nextArrTime: 161.86
# clockUpd()--SimClock: 158.34 nextArrTime: 161.86 nextDeptTime: 158.34
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 161.86 nextArrTime: 161.86 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 162.54
# arrive()--set nextArrTime: 165.45
# clockUpd()--SimClock: 162.54 nextArrTime: 165.45 nextDeptTime: 162.54
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 165.45 nextArrTime: 165.45 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 166.08
# arrive()--set nextArrTime: 165.73
# clockUpd()--SimClock: 165.73 nextArrTime: 165.73 nextDeptTime: 166.08
# arrive()--set nextArrTime: 168.15
# clockUpd()--SimClock: 166.08 nextArrTime: 168.15 nextDeptTime: 166.08
# depart(): 1 persons in the queue!
# And set nextDeptTime: 166.09
# clockUpd()--SimClock: 166.09 nextArrTime: 168.15 nextDeptTime: 166.09
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 168.15 nextArrTime: 168.15 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 168.37
# arrive()--set nextArrTime: 169.36
# clockUpd()--SimClock: 168.37 nextArrTime: 169.36 nextDeptTime: 168.37
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 169.36 nextArrTime: 169.36 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 169.42
# arrive()--set nextArrTime: 170.32
# clockUpd()--SimClock: 169.42 nextArrTime: 170.32 nextDeptTime: 169.42
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 170.32 nextArrTime: 170.32 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 170.51
# arrive()--set nextArrTime: 170.94
# clockUpd()--SimClock: 170.51 nextArrTime: 170.94 nextDeptTime: 170.51
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 170.94 nextArrTime: 170.94 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 172.37
# arrive()--set nextArrTime: 173.86
# clockUpd()--SimClock: 172.37 nextArrTime: 173.86 nextDeptTime: 172.37
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 173.86 nextArrTime: 173.86 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 174.86
# arrive()--set nextArrTime: 174.5
# clockUpd()--SimClock: 174.5 nextArrTime: 174.5 nextDeptTime: 174.86
# arrive()--set nextArrTime: 175.82
# clockUpd()--SimClock: 174.86 nextArrTime: 175.82 nextDeptTime: 174.86
# depart(): 1 persons in the queue!
# And set nextDeptTime: 177.11
# clockUpd()--SimClock: 175.82 nextArrTime: 175.82 nextDeptTime: 177.11
# arrive()--set nextArrTime: 175.92
# clockUpd()--SimClock: 175.92 nextArrTime: 175.92 nextDeptTime: 177.11
# arrive()--set nextArrTime: 176.67
# clockUpd()--SimClock: 176.67 nextArrTime: 176.67 nextDeptTime: 177.11
# arrive()--set nextArrTime: 179.22
# clockUpd()--SimClock: 177.11 nextArrTime: 179.22 nextDeptTime: 177.11
# depart(): 3 persons in the queue!
# And set nextDeptTime: 177.9
# clockUpd()--SimClock: 177.9 nextArrTime: 179.22 nextDeptTime: 177.9
# depart(): 2 persons in the queue!
# And set nextDeptTime: 180.16
# clockUpd()--SimClock: 179.22 nextArrTime: 179.22 nextDeptTime: 180.16
# arrive()--set nextArrTime: 181.32
# clockUpd()--SimClock: 180.16 nextArrTime: 181.32 nextDeptTime: 180.16
# depart(): 2 persons in the queue!
# And set nextDeptTime: 181.11
# clockUpd()--SimClock: 181.11 nextArrTime: 181.32 nextDeptTime: 181.11
# depart(): 1 persons in the queue!
# And set nextDeptTime: 181.17
# clockUpd()--SimClock: 181.17 nextArrTime: 181.32 nextDeptTime: 181.17
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 181.32 nextArrTime: 181.32 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 181.9
# arrive()--set nextArrTime: 181.64
# clockUpd()--SimClock: 181.64 nextArrTime: 181.64 nextDeptTime: 181.9
# arrive()--set nextArrTime: 181.84
# clockUpd()--SimClock: 181.84 nextArrTime: 181.84 nextDeptTime: 181.9
# arrive()--set nextArrTime: 182.32
# clockUpd()--SimClock: 181.9 nextArrTime: 182.32 nextDeptTime: 181.9
# depart(): 2 persons in the queue!
# And set nextDeptTime: 183.32
# clockUpd()--SimClock: 182.32 nextArrTime: 182.32 nextDeptTime: 183.32
# arrive()--set nextArrTime: 186.3
# clockUpd()--SimClock: 183.32 nextArrTime: 186.3 nextDeptTime: 183.32
# depart(): 2 persons in the queue!
# And set nextDeptTime: 183.42
# clockUpd()--SimClock: 183.42 nextArrTime: 186.3 nextDeptTime: 183.42
# depart(): 1 persons in the queue!
# And set nextDeptTime: 185.25
# clockUpd()--SimClock: 185.25 nextArrTime: 186.3 nextDeptTime: 185.25
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 186.3 nextArrTime: 186.3 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 186.53
# arrive()--set nextArrTime: 192.65
# clockUpd()--SimClock: 186.53 nextArrTime: 192.65 nextDeptTime: 186.53
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 192.65 nextArrTime: 192.65 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 192.79
# arrive()--set nextArrTime: 193.66
# clockUpd()--SimClock: 192.79 nextArrTime: 193.66 nextDeptTime: 192.79
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 193.66 nextArrTime: 193.66 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: 193.72
# arrive()--set nextArrTime: 193.72
# clockUpd()--SimClock: 193.72 nextArrTime: 193.72 nextDeptTime: 193.72
# depart()--The queue is empty, RESET nextDeptTime: 9999999
# clockUpd()--SimClock: 193.72 nextArrTime: 193.72 nextDeptTime: 9999999
# arrive()--Begin serving--set nextDeptTime: